# %% [markdown]
# ## Day 6: Row Reduction Workshop
#
# The purpose of today's class meeting is simple -- build confidence with row reduction. As mentioned previously, you'll have a row reduction Gateway Exam in MAT350 worth 15% of your overall course grade, that you'll need to pass before the end of the semester. You'll be able to retake the Gateway Exam multiple times in order to show mastery. Each Gateway Exam will consist of four matrices for you to reduce within a 20-minute time limit. You'll need to reduce all matrices to their reduced row echelon forms correctly in order to pass.
#
# Your first attempt at the Gateway Exam will take place at the end of this class meeting. Prior to that, we'll take time to practice.

# %% [markdown]
# ### Completed Examples
#
# We'll begin with serveral completed examples of varying dimensions and difficulty. For each provided matrix, reduce the matrix to its reduced row echelon form.

# %% [markdown]
# #### Example 1: Square, Pivots in All Columns
#
# **Example:** $A = \begin{bmatrix} 1 & 4\\ -3 & 8\end{bmatrix}$
#
# > *Solution.*
# >
# > \begin{align} \begin{bmatrix} 1 & 4\\ -3 & 8\end{bmatrix} &\stackrel{R_2 \leftarrow R_2 + 3R_1}{\longrightarrow} \begin{bmatrix} 1 & 4\\ 0 & 20\end{bmatrix}\\
# &\stackrel{R_2 \leftarrow \frac{1}{20}R_2}{\longrightarrow} \begin{bmatrix} 1 & 4\\ 0 & 1\end{bmatrix}\\
# &\stackrel{R_1 \leftarrow R_1 + (-4)R_2}{\longrightarrow}\begin{bmatrix} 1 & 0\\ 0 & 1\end{bmatrix}~~\blacktriangledown
# \end{align}

# %% [markdown]
# #### Example 2: Non-Square, Some Columns Without Pivots
#
# **Example:** $C = \begin{bmatrix} 1 & 2 & 3 & 4 & 5\\
# 2 & 4 & 6 & 8 & 10\\
# 0 & 1 & 0 & -1 & -2\end{bmatrix}$
#
# > *Solution.*
# >
# > \begin{align}
# \begin{bmatrix} 1 & 2 & 3 & 4 & 5\\ 2 & 4 & 6 & 8 & 10\\ 0 & 1 & 0 & -1 & -2 \end{bmatrix}
# &\stackrel{R_2 \leftarrow R_2 - 2R_1}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & 3 & 4 & 5\\ 0 & 0 & 0 & 0 & 0\\ 0 & 1 & 0 & -1 & -2 \end{bmatrix} \\
# &\stackrel{R_3 \leftrightarrow R_2}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & 3 & 4 & 5\\ 0 & 1 & 0 & -1 & -2\\ 0 & 0 & 0 & 0 & 0 \end{bmatrix} \\
# &\stackrel{R_1 \leftarrow R_1 - 2R_2}{\longrightarrow}
# \begin{bmatrix} 1 & 0 & 3 & 6 & 9\\ 0 & 1 & 0 & -1 & -2\\ 0 & 0 & 0 & 0 & 0 \end{bmatrix}
# ~~\blacktriangledown
# \end{align}

# %% [markdown]
# #### Example 3: Square, Pivots in All Columns
#
# **Example:** $B = \begin{bmatrix} 2 & 4 & -2\\
# 1 & 3 & 1\\
# 3 & 9 & 1\end{bmatrix}$
#
# > *Solution.*
# >
# > \begin{align}
# \begin{bmatrix} 2 & 4 & -2\\ 1 & 3 & 1\\ 3 & 9 & 1 \end{bmatrix}
# &\stackrel{R_1 \leftarrow \frac{1}{2} R_1}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 1 & 3 & 1\\ 3 & 9 & 1 \end{bmatrix} \\
# &\stackrel{R_2 \leftarrow R_2 + (-1R_1)}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 0 & 1 & 2\\ 3 & 9 & 1 \end{bmatrix} \\
# &\stackrel{R_3 \leftarrow R_3 + (-3R_1)}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 0 & 1 & 2\\ 0 & 3 & 4 \end{bmatrix} \\
# &\stackrel{R_3 \leftarrow R_3 + (-3R_2)}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 0 & 1 & 2\\ 0 & 0 & -2 \end{bmatrix} \\
# &\stackrel{R_3 \leftarrow -\frac{1}{2} R_3}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 0 & 1 & 2\\ 0 & 0 & 1 \end{bmatrix} \\
# &\stackrel{R_2 \leftarrow R_2 + (-2R_3)}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & -1\\ 0 & 1 & 0\\ 0 & 0 & 1 \end{bmatrix} \\
# &\stackrel{R_1 \leftarrow R_1 + R_3}{\longrightarrow}
# \begin{bmatrix} 1 & 2 & 0\\ 0 & 1 & 0\\ 0 & 0 & 1 \end{bmatrix} \\
# &\stackrel{R_1 \leftarrow R_1 + (-2R_2)}{\longrightarrow}
# \begin{bmatrix} 1 & 0 & 0\\ 0 & 1 & 0\\ 0 & 0 & 1 \end{bmatrix}~~\blacktriangledown
# \end{align}

# %% [markdown]
# ### Examples
#
# The following sections include examples for you to try on your own. The subsections are loosely arranged by difficulty of the row reduction tasks. For each of the presented matrices, perform row reduction operations to convert the matrix into its equivalent reduced row echelon form.

# %% [markdown]
# #### Group 1
#
# 1. $A_1 = \begin{bmatrix}1 & 2\\ 0 & 3\end{bmatrix}$
#
# 2. $A_2 = \begin{bmatrix} 1 & 0\\ 0 & 1\\ 2 & 3\end{bmatrix}$
#
# 3. $A_3 = \begin{bmatrix} 1 & 2 & 3\\ 0 & 1 & 4\end{bmatrix}$

# %% [markdown]
# #### Group 2
#
# 4. $B_1 = \begin{bmatrix} 2 & 4 & -2\\ -1 & -2 & 1\\ 1 & 1 & 0\end{bmatrix}$
#
# 5. $B_2 = \begin{bmatrix} 1 & 2 & 1 & 0\\
# 2 & 4 & 3 & 1\\
# 1 & 1 & 2 & 3\end{bmatrix}$
#
# 6. $B_3 = \begin{bmatrix} 1 & 2 & 3\\
# 0 & 1 & 4\\
# 0 & 0 & 1\\
# 0 & 0 & 0\end{bmatrix}$

# %% [markdown]
# #### Group 3
#
# 7. $C_1 = \begin{bmatrix} 0 & 2 & 4 & 6\\
# 1 & 3 & 1 & 5\\
# 2 & 6 & 2 & 10\\
# 3 & 1 & 1 & 4\end{bmatrix}$
#
# 8. $C_2 = \begin{bmatrix} 1 & 1 & 1\\
# 2 & 2 & 2\\
# 1 & 0 & 1\\
# 0 & 1 & 2\\
# 3 & 3 & 3\end{bmatrix}$
#
# 9. $C_3 = \begin{bmatrix} 1 & 2 & 0 & 3 & 1\\
# 2 & 4 & -1 & 6 & 2\\
# -1 & -2 & 1 & -3 & 0\\
# 0 & 0 & 2 & 1 & 3\end{bmatrix}$
